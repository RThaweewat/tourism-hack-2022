# %%
import polars as pl
from datetime import date
import pandas as pd

# %%
df1 = pl.read_csv("tphs_import_1.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df2 = pl.read_csv("tphs_import_2.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df3 = pl.read_csv("tphs_import_3.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df4 = pl.read_csv("tphs_import_4.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df5 = pl.read_csv("tphs_import_6.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df6 = pl.read_csv("tphs_import_6.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df7 = pl.read_csv("tphs_import_7.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df8 = pl.read_csv("tphs_import_8.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df9 = pl.read_csv("tphs_import_9.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df10 = pl.read_csv("tphs_import_10.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df11 = pl.read_csv("tphs_import_11.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df12 = pl.read_csv("tphs_import_12.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df13 = pl.read_csv("tphs_import_13.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df14 = pl.read_csv("tphs_import_14.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df15 = pl.read_csv("tphs_import_15.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df16 = pl.read_csv("tphs_import_16.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df17 = pl.read_csv("tphs_import_17.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))
df18 = pl.read_csv("tphs_import_18.csv", ignore_errors=True).with_columns(pl.all().cast(pl.Utf8, strict=False))

# %%
ytp_info = pd.read_csv("C:\\Users\\Thaweewat\\Desktop\\url(3).csv")
ytp_info.head()
# Out:
#                                                  url
# 0  https://www.makemytrip.com/hotels/hotel-detail...
# 1  https://www.makemytrip.com/hotels/hotel-detail...
# 2  https://www.makemytrip.com/hotels/hotel-detail...
# 3  https://www.makemytrip.com/hotels/hotel-detail...
# 4  https://www.makemytrip.com/hotels/hotel-detail...

# %%
test = ytp_info['url'].values.tolist()

# %%
words = [w.replace(r"\'", "\"") for w in test]

# %%
import json
print(json.dumps(test))
# Out:
# ["https://www.makemytrip.com/hotels/hotel-details?hotelId=201603101001288759&_uCurrency=INR&checkin=11282022&checkout=11292022&city=CTPHUKE&country=THA&lat=7.88249&lng=98.27657&locusId=CTPHUKE&locusType=city&rank=1&roomStayQualifier=2e0e&searchText=Phuket&viewType=LUXE&mtkeys=defaultMtkey", "https://www.makemytrip.com/hotels/hotel-details?hotelId=4190725563793888&_uCurrency=INR&checkin=11282022&checkout=11292022&city=CTPHUKE&country=THA&lat=7.88109&lng=98.27815&locusId=CTPHUKE&locusType=city&rank=2&roomStayQualifier=2e0e&searchText=Phuket&viewType=LUXE&mtkeys=defaultMtkey", "https://www.makemytrip.com/hotels/hotel-details?hotelId=4190725563794548&_uCurrency=INR&checkin=11282022&checkout=11292022&city=CTPHUKE&country=THA&lat=7.89878&lng=98.30037&locusId=CTPHUKE&locusType=city&rank=3&roomStayQualifier=2e0e&searchText=Phuket&mtkeys=defaultMtkey", "https://www.makemytrip.com/hotels/hotel-details?hotelId=4190725563794994&_uCurrency=INR&checkin=11282022&checkout=11292022&city=CTPHUKE&count
# ...

# %%
review = pl.read_csv("D:\hackathon\hotel_review1_part_*.csv")

# %%
review
# Out:
# shape: (202387, 13)
# ┌───────────┬────────┬────────────┬──────────┬─────┬───────────┬─────────┬────────────┬────────────┐
# │ displayNa ┆ rating ┆ publish_pl ┆ title    ┆ ... ┆ travel_ty ┆ name    ┆ hotel_rati ┆ hotel_loca │
# │ me        ┆ ---    ┆ atform     ┆ ---      ┆     ┆ pe        ┆ ---     ┆ ng         ┆ tion       │
# │ ---       ┆ i64    ┆ ---        ┆ str      ┆     ┆ ---       ┆ str     ┆ ---        ┆ ---        │
# │ str       ┆        ┆ str        ┆          ┆     ┆ str       ┆         ┆ i64        ┆ str        │
# ╞═══════════╪════════╪════════════╪══════════╪═════╪═══════════╪═════════╪════════════╪════════════╡
# │ PaulB     ┆ 5      ┆ Mobile     ┆ Great    ┆ ... ┆ Family    ┆ Amari   ┆ 4          ┆ Patong     │
# │           ┆        ┆            ┆ hotel    ┆     ┆           ┆ Phuket  ┆            ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
review.filter(pl.col("clean_country") == "India").to_pandas().to_csv("india_trip_review.csv")

# %%
df_vertical_concat = pl.concat(
	[
		df1,
		df2,
		df3,
		df4,
		df5,
		df6,
		df7,
		df8,
		df9,
		df10,
		df11,
		df12,
		df13,
		df14,
		df15,
		df16,
		df17,
		df18
	],
	how="vertical",
)

# %%
df_phuket = df_vertical_concat.filter((pl.col("province") == "Phuket"))

# %%
df_phuket_full = df_phuket.to_pandas()

# %%
df_phuket_full.to_csv("df_phuket_final.csv")

# %%
df_phuket_full.pivot_table(values="import_id", index="nationality", aggfunc="count")
# Out:
#                  import_id
# nationality
# Afghan                  38
# Albanian               237
# Algerian               216
# American             20641
# American Samoan         11
# ...                    ...
# Yemeni                  80
# Zambian                  6
# Zimbabwean              62
# liSwati                  5
# none                    63
#
# [197 rows x 1 columns]

# %%
df_india = df_india.with_column(pl.col("checkInDate").str.strptime(pl.Date, fmt="%Y-%m-%d"))
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6024\1408571179.py in <cell line: 1>()
# ----> 1 df_india = df_india.with_column(pl.col("checkInDate").str.strptime(pl.Date, fmt="%Y-%m-%d"))
#       2 df_india
#
# ~\anaconda3\lib\site-packages\polars\internals\dataframe\frame.py in with_column(self, column)
#    4207
#    4208         """
# -> 4209         return self.lazy().with_column(column).collect(no_optimization=True)
#    4210
#    4211     def hstack(
#
# ~\anaconda3\lib\site-packages\polars\utils.py in wrapper(*args, **kwargs)
#     308         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     309             _rename_kwargs(fn.__name__, kwargs, aliases)
# --> 310             return fn(*args, **kwargs)
#     311
#     312         return wrapper
#
# ...

# %%
df_india.with_column(pl.col("checkInDate"))

# %%
df_india_final = df_india.to_pandas()

# %%
cd
# Out:
# C:\Users\Thaweewat

# %%
df_india_final.to_csv("df_india_final.csv")

# %%
df_india_final.plot(x="checkInDate", y="")

# %%
df_phuket_full

# %%
df_phuket_full.pivot_table(index="checkInDate", values="import_id", aggfunc="count").plot()
# Out:
# <AxesSubplot:xlabel='checkInDate'>

# %%
wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df_phuket_full.value_counts('nationality')
# Out:
# nationality
# Russian              78622
# British              49495
# German               38334
# French               34813
# Australian           29461
#                      ...
# Pitcairn Islander        1
# Mosotho                  1
# Seychellois              1
# Central African          1
# Solomon Islander         1
# Length: 197, dtype: int64

# %%
# !pip install wordcloud
# Out:
# ...
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# ...

# %%
rev_india = review.filter(pl.col("clean_country") == "India").to_pandas()

# %%
rev_india
# Out:
#           displayName  rating publish_platform  \
# 0         ashish12022       3            Other
# 1     kedawatanuj1997       3            Other
# 2        Ankitpatwari       4           Mobile
# 3              powler       1           Mobile
# 4           Mili Shah       3           Mobile
# ...               ...     ...              ...
# 4919          Snale D       5           Mobile
# 4920            Afroj       5           Mobile
# 4921        Mudrika G       5           Mobile
# 4922          Varshaa       3            Other
# 4923         Sanjay S       5            Other
#
#                                                   title  \
# 0     Worst property to stay with unhygienic and rud...
# 1                                              Review w
# 2                                  Stay at Patong beach
# 3                     Poor and annoying holiday spoiler
# 4                                                Decent
# ...

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
rev_india_new = pd.read_csv("D:\hackathon\makemytrip.csv")

# %%
text = " ".join(i for i in rev_india_new .text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(i for i in rev_india_new.context)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_india_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21053 entries, 0 to 21052
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0                  21053 non-null  object
#  1   import_id      21053 non-null  object
#  2   title          21053 non-null  object
#  3   nationality    21053 non-null  object
#  4   flightNumber   21033 non-null  object
#  5   hotelName      21053 non-null  object
#  6   hotel_id       21053 non-null  object
#  7   province       21053 non-null  object
#  8   checkInDate    21053 non-null  datetime64[ns]
#  9   checkOutDate   21053 non-null  object
#  10  sha_id         21053 non-null  object
#  11  arrivalDate    21053 non-null  object
#  12  departureFrom  820 non-null    object
#  13  Airport        21053 non-null  object
#  14  entryType      21053 non-null  object
#  15  id             21053 non-null  object
#  16  approve_date   21053 non-null  object
# ...

# %%
df_india_final.checkInDate.max()
# Out:
# Timestamp('2022-06-07 00:00:00')

# %%
df_india_final.checkInDate.min()
# Out:
# Timestamp('2021-12-16 00:00:00')

# %%
df_india_final.pivot_table(index="hotelName", values="import_id", aggfunc="count")
# Out:
#                                                     import_id
# hotelName
# \t LetsPhuket Twin Sands Resort & Spa (SHA Plus+)           1
# AMARI PHUKET                                                2
# AMATARA WELLNESS RESORT                                     1
# ANDARA RESORT AND VILLAS                                    2
# ASHLEE HUB HOTEL PATONG                                   126
# ...                                                       ...
# oak wood hotel                                              3
# sushil                                                      1
# u sabai living hotel                                        1
# ์Naiyaburee Boutique Resort                                 1
# ์Nipa Resort Patong Beach                                  45
#
# [474 rows x 1 columns]

# %%
df_india_final.pivot_table(index="flightNumber", values="import_id", columns="Airport",aggfunc="count")
# Out:
# Airport       BKK  HKT  KBV
# flightNumber
#  EK 378       NaN  1.0  NaN
#  EY430        NaN  1.0  NaN
#  G8 1563      NaN  1.0  NaN
# 0840          NaN  3.0  NaN
# 0842          NaN  5.0  NaN
# ...           ...  ...  ...
# Y974RM        NaN  1.0  NaN
# ZFZZ5H        NaN  5.0  NaN
# ZHLKHS        NaN  1.0  NaN
# g8-21         NaN  1.0  NaN
# g821          NaN  2.0  NaN
#
# [585 rows x 3 columns]

# %%
df_india_final
# Out:
#              import_id title nationality  \
# 0       2471      2472   Mr.      Indian
# 1       2476      2477   Ms.      Indian
# 2       2770      2771   Mr.      Indian
# 3       3910      3911   Mr.      Indian
# 4       6672      6675   Mr.      Indian
# ...      ...       ...   ...         ...
# 21048  88430   2599202  Mrs.      Indian
# 21049  88433   2599205   Ms.      Indian
# 21050  88434   2599206   Ms.      Indian
# 21051  88446   2599218   Mr.      Indian
# 21052  88473   2599245  Mrs.      Indian
#
#                                             flightNumber  \
# 0                                                   g821
# 1                                                   g821
# 2                                                  g8-21
# 3                            MH-191 and MH-786 and G8-74
# 4      Delhi To Malaysia Flight number is  MH-191  & ...
# ...                                                  ...
# 21048                                              EK396
# ...

# %%
df_india_final.groupby("flightNumber").count()
# Out:
#                  import_id  title  nationality  hotelName  hotel_id  province  \
# flightNumber
#  EK 378       1          1      1            1          1         1         1
#  EY430        1          1      1            1          1         1         1
#  G8 1563      1          1      1            1          1         1         1
# 0840          3          3      3            3          3         3         3
# 0842          5          5      5            5          5         5         5
# ...          ..        ...    ...          ...        ...       ...       ...
# Y974RM        1          1      1            1          1         1         1
# ZFZZ5H        5          5      5            5          5         5         5
# ZHLKHS        1          1      1            1          1         1         1
# g8-21         1          1      1            1          1         1         1
# g821          2          2      2            2          2         2         2
#
# ...

# %%
df_vertical_concat
# Out:
# shape: (300000, 35)
# ┌───────┬───────────┬───────┬───────────┬─────┬────────────┬────────────┬────────────┬─────────────┐
# │       ┆ import_id ┆ title ┆ nationali ┆ ... ┆ noshow_sta ┆ noshow_sta ┆ entryChann ┆ h_passNo    │
# │ ---   ┆ ---       ┆ ---   ┆ ty        ┆     ┆ mp1        ┆ mp2        ┆ el         ┆ ---         │
# │ i64   ┆ i64       ┆ str   ┆ ---       ┆     ┆ ---        ┆ ---        ┆ ---        ┆ str         │
# │       ┆           ┆       ┆ str       ┆     ┆ str        ┆ str        ┆ str        ┆             │
# ╞═══════╪═══════════╪═══════╪═══════════╪═════╪════════════╪════════════╪════════════╪═════════════╡
# │ 0     ┆ 1         ┆ Mr.   ┆ German    ┆ ... ┆ null       ┆ null       ┆ AIR        ┆ b'$2b$12$ot │
# │       ┆           ┆       ┆           ┆     ┆            ┆            ┆            ┆ 4/Ix7ZOxr/y │
# │       ┆           ┆       ┆           ┆     ┆            ┆            ┆            ┆ 8U5TJbrXeK. │
# ...
