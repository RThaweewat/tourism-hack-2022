# %%
import pandas as pd
import numpy as np

# %%
hotel_raw = pd.read_csv("D:\hackathon\data_hotel_01.csv")

# %% [markdown]
# $$
# Question: Is cryptocurrency pyramid scheme?
# \\
# Answer: Yes
# $$

# %%
dfCopy = hotel_raw.copy()

dfCopy.loc[:,'LATITUDE'] = ((dfCopy.loc[:, 'hotel_latitude']*1000).apply(np.floor))/1000
dfCopy.loc[:,'LONGITUDE'] = ((dfCopy.loc[:, 'hotel_longitude']*1000).apply(np.floor))/1000
dfCopy.loc[:,'LatLonRange'] = dfCopy.loc[:,'hotel_latitude'].map(str) + '-' + dfCopy.loc[:, 'hotel_longitude'].map(str)

df_grouped = dfCopy.groupby(['LatLonRange', 'LATITUDE', 'LONGITUDE'])
df_grouped.head()
# Out:
#       Unnamed: 0 property_result_type  \
# 0              0    RecurringProperty
# 1              1    RecurringProperty
# 2              2    RecurringProperty
# 3              3      SoldOutProperty
# 4              4    RecurringProperty
# ...          ...                  ...
# 2270        2270       NormalProperty
# 2271        2271       NormalProperty
# 2272        2272      SoldOutProperty
# 2273        2273       NormalProperty
# 2274        2274       NormalProperty
#
#                                               highlight  \
# 0     ['shopping', 'sightseeing', 'nightlife', 'rest...
# 1                       ['beaches', 'romantic locales']
# 2                            ['restaurants', 'beaches']
# 3     ['shopping', 'nightlife', 'restaurants', 'beac...
# 4     ['shopping', 'nightlife', 'restaurants', 'beac...
# ...                                                 ...
# 2270                    ['beaches', 'romantic locales']
# 2271  ['shopping', 'nightlife', 'restaurants', 'beac...
# 2272  ['shopping', 'nightlife', 'restaurants', 'beac...
# 2273  ['shopping', 'nightlife', 'restaurants', 'beac...
# 2274               ['convenient public transportation']
#
#                                              hotel_name  award_year  \
# 0              Royal Phuket City Hotel (SHA Extra Plus)         NaN
# 1               Dewa Phuket Resort & Villas (SHA Plus+)      2019.0
# 2                  The SIS Kata Resort (SHA Extra Plus)         NaN
# 3     Phuket Marriott Resort & Spa, Merlin Beach SHA...         NaN
# 4                  Kalima Resort & Spa (SHA Extra plus)         NaN
# ...                                                 ...         ...
# 2270                   The Regent Bangtao Phuket by VIP         NaN
# 2271                                        Cello Hotel         NaN
# 2272                                 3plus1hostelphuket         NaN
# 2273                                          7Q Patong         NaN
# 2274                                   Villa Leelawadee         NaN
#
#           area_name property_type  rating  renovation_info_year  \
# 0       Phuket Town         Hotel     5.0                2021.0
# 1     Naiyang Beach         Hotel     5.0                   NaN
# 2              Kata         Hotel     5.0                   NaN
# 3            Patong         Hotel     5.0                   NaN
# 4            Patong         Hotel     5.0                2021.0
# ...             ...           ...     ...                   ...
# 2270      Bang Thao      NonHotel     4.5                   NaN
# 2271         Patong         Hotel     2.0                   NaN
# 2272         Patong         Hotel     3.0                   NaN
# 2273         Patong         Hotel     3.0                   NaN
# 2274         Ao Por         Hotel     4.0                   NaN
#
#       hotel_latitude  ...                                         facilities  \
# 0           7.882801  ...  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1           8.092709  ...  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 2           7.812412  ...  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 3           7.883696  ...  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 4           7.917336  ...  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# ...              ...  ...                                                ...
# 2270        7.994883  ...                                                 []
# 2271        7.890340  ...                                                 []
# 2272        7.898893  ...                                                 []
# 2273        7.905789  ...                                                 []
# 2274        8.076360  ...                                                 []
#
#      hotel_tag_name  hotel_view  soldout_average_price host_level_name  \
# 0               NaN         NaN                    NaN             NaN
# 1               NaN         NaN                    NaN             NaN
# 2               NaN         NaN                    NaN             NaN
# 3            Luxury    Sea View            8618.061916             NaN
# 4               NaN    Sea View                    NaN             NaN
# ...             ...         ...                    ...             ...
# 2270            NaN         NaN                    NaN             NaN
# 2271            NaN         NaN                    NaN             NaN
# 2272            NaN         NaN              72.864480             NaN
# 2273            NaN         NaN                    NaN             NaN
# 2274            NaN         NaN                    NaN             NaN
#
#      price_promotion price_actual  LATITUDE LONGITUDE  \
# 0            1611.26      1914.18     7.882    98.394
# 1            2215.51      2630.08     8.092    98.299
# 2            1997.28      2372.77     7.812    98.299
# 3               0.00         0.00     7.883    98.272
# 4            3132.00      3720.82     7.917    98.284
# ...              ...          ...       ...       ...
# 2270            0.00         0.00     7.994    98.300
# 2271            0.00         0.00     7.890    98.303
# 2272            0.00         0.00     7.898    98.301
# 2273            0.00         0.00     7.905    98.298
# 2274            0.00         0.00     8.076    98.432
#
#                               LatLonRange
# 0       7.88280080029386-98.3945701057901
# 1       8.09270888501092-98.2993300259113
# 2       7.81241232820195-98.2996317744255
# 3       7.88369575620107-98.2725298387231
# 4       7.91733641050147-98.2844638824463
# ...                                   ...
# 2270    7.99488316095498-98.3006001736794
# 2271   7.890339851379394-98.3039321899414
# 2272  7.898893445916595-98.30178013561668
# 2273  7.905788595022053-98.29836313147098
# 2274   8.076359748840332-98.4322509765625
#
# [2222 rows x 36 columns]

# %%
# Find Number of Fires That Occured in Each Group
fire_count = df_grouped['count_reviwer'].agg(['count']).reset_index()

# Find Average Fire Size in Each Group
fire_avgSize = df_grouped['count_reviwer'].agg(['mean']).reset_index()

# %%
tourism = pd.read_csv("D:\hackathon\index.csv").query('province == "ภูเก็ต"')
tourism
# Out:
#       Unnamed: 0                      source  \
# 203          203                  กรมศิลปากร
# 204          204                  กรมศิลปากร
# 205          205                  กรมศิลปากร
# 207          207                  กรมศิลปากร
# 208          208                  กรมศิลปากร
# ...          ...                         ...
# 1285        1285  การท่องเที่ยวแห่งประเทศไทย
# 1286        1286  การท่องเที่ยวแห่งประเทศไทย
# 1287        1287  การท่องเที่ยวแห่งประเทศไทย
# 1288        1288  การท่องเที่ยวแห่งประเทศไทย
# 1289        1289  การท่องเที่ยวแห่งประเทศไทย
#
#                                                   title img_url  \
# 203                          อาคารศาลากลางจังหวัดภูเก็ต     NaN
# 204   สำนักงานขายประจำประเทศไทย ภาคใต้ตอนบน บริษัท ก...     NaN
# 205                                 อาคารสำนักงานที่ดิน     NaN
# 207                    ที่ทำการไปรษณีย์โทรเลข(หลังเก่า)     NaN
# 208                                โรงเรียนภูเก็ตไทยหัว     NaN
# ...                                                 ...     ...
# 1285                            แอฟโฟรไดท์ คาบาเร่ทโชว์     NaN
# 1286                                         โคกชนะพม่า     NaN
# 1287                                       โรงแรมออนออน     NaN
# 1288                                          ไดโนปาร์ค     NaN
# 1289                                           ไร่วานิช     NaN
#
#                     title_en                                    payment  \
# 203                      NaN                                        NaN
# 204                      NaN                                        NaN
# 205                      NaN                                        NaN
# 207                      NaN                                        NaN
# 208                      NaN                                        NaN
# ...                      ...                                        ...
# 1285  Aphrodite Cabaret Show  {'มีค่าใช้จ่าย': 800.0, 'หมายเหตุ': None}
# 1286                   ไม่มี   {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1287             On On Hotel   {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1288               Dino Park   {'มีค่าใช้จ่าย': 60.0, 'หมายเหตุ': None}
# 1289             Vanich Farm    {'มีค่าใช้จ่าย': 0.0, 'หมายเหตุ': None}
#
#                                                    tags  \
# 203   ['กระเบื้อง', 'หลังคา', 'ดอกไม้', 'ไม้_สัก', '...
# 204         ['ศิลปะ', 'ภาคใต้', 'สำนักงาน', 'ศิลปกรรม']
# 205                                         ['ระเบียง']
# 207   ['สี่เหลี่ยม', 'หลังคา', 'ชายทะเล', 'ศิลปกรรม'...
# 208   ['หลังคา', 'โรงเรียน', 'ศาลเจ้า', 'ภูเก็ต', 'ง...
# ...                                                 ...
# 1285                                                NaN
# 1286                                                NaN
# 1287                                                NaN
# 1288                                                NaN
# 1289                                                NaN
#
#                                                    info  \
# 203   ลักษณะอาคารเป็นอาคาร2ชั้น พื้นอาคารสูงกว่าพื้น...
# 204   อาคาร 2 ชั้น ศิลปกรรมแบบ โรมาเนสผสมจีนด้านหน้า...
# 205   อาคารตึกชั้นเดียว ยกพื้นสูง ภายในแบ่งออกเป็น 5...
# 207   เป็นสถาปัตยกรรมโบราณที่มีคุณค่าทางประวัติศาสตร...
# 208   อาคารเรียนของโรงเรียนภูเก็ตไทยหัวในปัจจุบัน เป...
# ...                                                 ...
# 1285              ชมการแสดงคาบาเร่ทโชว์ จากสาวประเภทสอง
# 1286  สมรภูมิรบพม่า พ.ศ.2328 \nเป็นอนุสรณ์สถานถลางชน...
# 1287  สร้างเมื่อ พ.ศ.2472 โดยเจ้าของจ้างช่างจากเมือง...
# 1288  มินิกอล์ฟขนาด 18 หลุม ในบรรยากาศโลกบ้านปีซึ่งม...
# 1289  ไร่วานิช”\tถูกออกแบบเพื่อถ่ายทอดสภาพแวดล้อมกรร...
#
#                                                lda_tags             hours  \
# 203   ['กระเบื้อง', 'หลังคา', 'ดอกไม้', 'ไม้_สัก', '...                []
# 204   ['ศิลปะ', 'ภาคใต้', 'สำนักงาน', 'ศิลปกรรม', 'พ...                []
# 205   ['ระเบียง', 'ปราสาท', 'หนองน้ำ', 'สระน้ำ', 'โบ...                []
# 207   ['สี่เหลี่ยม', 'หลังคา', 'ชายทะเล', 'ศิลปกรรม'...                []
# 208   ['หลังคา', 'โรงเรียน', 'ศาลเจ้า', 'ภูเก็ต', 'ง...                []
# ...                                                 ...               ...
# 1285                                                NaN               NaN
# 1286                                                NaN               NaN
# 1287                                                NaN
# 1288                                                NaN  10.00 - 24.00 น.
# 1289                                                NaN    10.00-19.00 น.
#
#                                                contacts  \
# 203                                                  {}
# 204                                                  {}
# 205                                                  {}
# 207                                                  {}
# 208                                                  {}
# ...                                                 ...
# 1285  {'tel': '0 7661 2888', 'website': 'www.phuket-...
# 1286      {'tel': None, 'website': None, 'email': None}
# 1287  {'tel': '0 7621 1154', 'website': None, 'email...
# 1288  {'tel': '0 7633 0625', 'website': None, 'email...
# 1289  {'tel': '076211536', 'website': 'www.vanichfar...
#
#                                                new_tags  \
# 203                                          ['ดอกไม้']
# 204                                           ['ศิลปะ']
# 205                                                  []
# 207                                         ['ชายทะเล']
# 208                             ['ศาลเจ้า', 'งานศิลปะ']
# ...                                                 ...
# 1285                                                 []
# 1286       ['อนุสรณ์สถาน', 'แหล่งโบราณคดี', 'โบราณคดี']
# 1287                                                 []
# 1288                                     ['พิพิธภัณฑ์']
# 1289  ['ทุ่ง', 'การเกษตร', 'ธรรมชาติ', 'เรียนรู้', '...
#
#                                            new_tat_tags  latitude  longitude  \
# 203   ['ศูนย์ศึกษาธรรมชาติ/แหล่งท่องเที่ยวทางดอกไม้แ...     7.890     98.400
# 204                                ['วัฒนธรรมท้องถิ่น']     7.880     98.390
# 205                                                  []     7.890     98.400
# 207                                        ['ธรรมชาติ']     7.880     98.400
# 208   ['โบราณสถาน/ศาสนสถาน/สถานปฏิบัติธรรม', 'ศาสนสถ...     7.880     98.390
# ...                                                 ...       ...        ...
# 1285                                                 []     7.914     98.338
# 1286  ['อนุสาวรีย์/พิพิธภัณฑ์', 'โบราณสถาน', 'โบราณส...     8.116     98.425
# 1287                                                 []     7.888     98.394
# 1288            ['พิพิธภัณฑ์', 'อนุสาวรีย์/พิพิธภัณฑ์']     7.821     98.285
# 1289  ['ศูนย์ศึกษาธรรมชาติ/แหล่งท่องเที่ยวทางดอกไม้แ...     7.834     98.423
#
#                                                 address  subdistrict  \
# 203   เลขที่ - หมู่ - บ้าน -\nถนน ดำรง ตลาดใหญ่ เมือ...     ตลาดใหญ่
# 204   เลขที่ 78/1 หมู่ - บ้าน -\nถนน ระนอง ตลาดใหญ่ ...     ตลาดใหญ่
# 205   เลขที่ - หมู่ - บ้าน -\nถนน ดำรง ตลาดใหญ่ เมือ...     ตลาดใหญ่
# 207   เลขที่ 158 หมู่ - บ้าน -\nถนน มนตรี ตลาดใหญ่ เ...     ตลาดใหญ่
# 208   เลขที่ 28 หมู่ - บ้าน -\nถนน กระบี่ ตลาดเหนือ ...    ตลาดเหนือ
# ...                                                 ...          ...
# 1285  99/100 หมู่ 1 None เฉลิมพระเกียรติ ร.9 กะทู้ ก...        กะทู้
# 1286  None None เทพกระษัตรี เทพกระษัตรี ถลาง ภูเก็ต ...  เทพกระษัตรี
# 1287    19 None พังงา ตลาดใหญ่ เมืองภูเก็ต ภูเก็ต 83000     ตลาดใหญ่
# 670        วัดพระใหญ่ "พระพุทธมิ่งมงคลเอกนาคคีรี"
# 675                       วัดไชยธาราราม (วัดฉลอง)
# 701               ชุมชนย่านเมืองเก่าจังหวัดภูเก็ต
# 702                        วัดพระทองหรือวัดพระผุด
# 703                ศูนย์ศิลปวัฒนธรรมจังหวัดภูเก็ต
# 1180                                    วัดพระทอง
# 1181                               วัดพระนางสร้าง
# 1182                            วัดม่วงโกมารภัจจ์
# 1183                                 วัดศรีสุนทร
# 1184                                วัดสีลสุภาราม
# 1185                                วัดไชยธาราราม
# 1221                 หอทะเบียนที่ดินจังหวัดภูเก็ต
#
#                                                 img_url             title_en  \
# 203                                                 NaN                  NaN
# 209                                                 NaN                  NaN
# 210                                                 NaN                  NaN
# 214                                                 NaN                  NaN
# 215                                                 NaN                  NaN
# 282                                                 NaN                  NaN
# 461   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 471   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 512   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 605   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 653   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 670   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 675   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 701   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 702   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 703   ['https://www.thailandtourismdirectory.go.th/t...                  NaN
# 1180                                                NaN        Wat Phrathong
# 1181                                                NaN   Wat Phra Nang Sang
# 1182                                                NaN  Wat Muang Komarapat
# 1183                                                NaN       Wat Si Sunthon
# 1184                                                NaN       Wat Silsuparam
# 1185                                                NaN   Wat Chai Thara Ram
# 1221                                                NaN   Land Office Phuket
#
#                                                 payment  \
# 203                                                 NaN
# 209                                                 NaN
# 210                                                 NaN
# 214                                                 NaN
# 215                                                 NaN
# 282                                   ไม่เก็บค่าเข้าชม
# 461   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 471   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 512   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 605   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 653   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 670   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 675   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 701   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 702   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 703   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...
# 1180           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1181           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1182           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1183           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1184           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1185           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
# 1221           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}
#
#                                                    tags  \
# 203   ['กระเบื้อง', 'หลังคา', 'ดอกไม้', 'ไม้_สัก', '...
# 209   ['พระพุทธรูป', 'หินอ่อน', 'อนุสรณ์', 'โบราณ', ...
# 210                          ['ภูเก็ต', 'รัตนโกสินทร์']
# 214   ['เจดีย์', 'รัตนโกสินทร์', 'โบราณ', 'ศิลปะ', '...
# 215                                             ['วัด']
# 282                      ['โบราณ', 'พิพิธภัณฑ์', 'วัด']
# 461                                                 NaN
# 471                                                 NaN
# 512                                                 NaN
# 605                                                 NaN
# 653                                                 NaN
# 670                                                 NaN
# 675                                                 NaN
# 701                                                 NaN
# 702                                                 NaN
# 703                                                 NaN
# 1180                                                NaN
# 1181                                                NaN
# 1182                                                NaN
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1221                                                NaN
#
#                                                    info  \
# 203   ลักษณะอาคารเป็นอาคาร2ชั้น พื้นอาคารสูงกว่าพื้น...
# 209   พระพุทธรูปทองคำ สมัยสุโขทัย มีอายุประมาณ 700ปี...
# 210               อาคารสถาปัตยกรรมยุโรปสมัยรัตนโกสินทร์
# 214   เป็นเจดีย์โบราณตั้งเรียงกัน 3 องค์ เป็นเจดีย์ก...
# 215                                                 NaN
# 282   ศิลปวัตถุประเภทต่างๆ กว่า 1,000 ชิ้น เช่น เครื...
# 461   วัดพระนางสร้างเป็นวัดคู่บ้านคู่เมืองวัดหนึ่งขอ...
# 471   วัดมงคลวราราม (วัดในยาง) ตั้งอยู่หมู่ที่ 1 บ้า...
# 512   พระพุทธมิ่งมงคลเอกนาคคีรี หรือ พระใหญ่ ภูเก็ต ...
# 605   สำหรับการเดินทางมายังวัดสีลสุภาราม(วัดหลวงปู่ส...
# 653   วัดม่วงโกมารภัจจ์ เป็นวัดร้างอยู่ในความดูแลของ...
# 670   วัดพระใหญ่ พระพุทธมิ่งมงคลเอกนาคาคีรี ตั้งอยู่...
# 675   วัดฉลอง (วัดไชยธาราราม) อยู่ห่างจากตัวเมือง 8 ...
# 701    เส้นทางการเดินชมตึกเก่าชิโนโปรตุกีสนั้นจะมีทั...
# 702   วัดพระผุดหรือวัดพระทองอยู่ห่างจากตัวเมืองภูเก็...
# 703   ตั้งอยู่ในมหาวิทยาลัยราชภัฏภูเก็ต เป็นสถานที่จ...
# 1180  ชมพระพุทธรูปทองคำที่ผุดขึ้นมาครึ่งองค์ เป็นศูน...
# 1181  เป็นวัดที่เก่าแก่ เป็นแหล่งประวัติศาสตร์เมืองถ...
# 1182  มีพระพุทธรูปปูนปั้นครี่งท่อนสกุลช่างถลางใกล้พร...
# 1183  วัดศรีสุนทร หรือ วัดบ้านพอน หรือ วัดบ้านลิพอน ...
# 1184  แหล่งปฏิบัติธรรมหลวงปู่สุภา ถนุตศรีโลเกจิชื่อด...
# 1185  วัดคู่บ้านคู่เมืองภูเก็ตนมัสการหลวงพ่อแช่ม ภาย...
# 1221      ชมอาคารสำนักงานที่ดินตึกเก่าสไตล์ชิโนโปรตุกีส
#
#                                                lda_tags  \
# 203   ['กระเบื้อง', 'หลังคา', 'ดอกไม้', 'ไม้_สัก', '...
# 209   ['พระพุทธรูป', 'หินอ่อน', 'อนุสรณ์', 'โบราณ', ...
# 210   ['ภูเก็ต', 'รัตนโกสินทร์', 'บ้านเรือน', 'ศิลปะ...
# 214   ['เจดีย์', 'รัตนโกสินทร์', 'โบราณ', 'ศิลปะ', '...
# 215                                             ['วัด']
# 282   ['โบราณ', 'พิพิธภัณฑ์', 'วัด', 'ตลาด', 'ประวัต...
# 461                                                 NaN
# 471                                                 NaN
# 512                                                 NaN
# 605                                                 NaN
# 653                                                 NaN
# 670                                                 NaN
# 675                                                 NaN
# 701                                                 NaN
# 702                                                 NaN
# 703                                                 NaN
# 1180                                                NaN
# 1181                                                NaN
# 1182                                                NaN
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1221                                                NaN
#
#                                                   hours  \
# 203                                                  []
# 209                                                  []
# 210                                                  []
# 214                                                  []
# 215                                                  []
# 282                                                  []
# 461   {'วันอาทิตย์': ['0800', '1700'], 'วันจันทร์': ...
# 471   {'วันอาทิตย์': ['0500', '1800'], 'วันจันทร์': ...
# 512   {'วันอาทิตย์': ['0900', '1800'], 'วันจันทร์': ...
# 605   {'วันอาทิตย์': ['0800', '1700'], 'วันจันทร์': ...
# 653   {'วันอาทิตย์': ['0800', '1700'], 'วันจันทร์': ...
# 670   {'วันอาทิตย์': ['0800', '1930'], 'วันจันทร์': ...
# 675   {'วันอาทิตย์': ['0700', '1800'], 'วันจันทร์': ...
# 701   {'วันอาทิตย์': ['0700', '2300'], 'วันจันทร์': ...
# 702   {'วันอาทิตย์': ['0700', '1700'], 'วันจันทร์': ...
# 703   {'วันอาทิตย์': ['0830', '1630'], 'วันจันทร์': ...
# 1180                                   08.00 - 17.30 น.
# 1181                                                NaN
# 1182                                                NaN
# 1183                                                NaN
# 1184                          เปิดทุกวัน 09.00-17.00 น.
# 1185                                   07.00 - 17.00 น.
# 1221                                     08.30-16.30 น.
#
#                                                contacts  \
# 203                                                  {}
# 209                                                  {}
# 210                                                  {}
# 214                                                  {}
# 215                                                  {}
# 282                                                  {}
# 461   {'tel': None, 'website': 'http://www.sac.or.th...
# 471   {'tel': '07632814616', 'website': 'www.sakhu.g...
# 512   {'tel': ' 081 891 3827', 'website': None, 'ema...
# 605   {'tel': '076280774', 'website': 'http://www.ph...
# 653   {'tel': None, 'website': None, 'email': None, ...
# 670   {'tel': None, 'website': None, 'email': 'info@...
# 675   {'tel': '076381226', 'website': 'www.watchalon...
# 701   {'tel': ' 076 211 036', 'website': None, 'emai...
# 702   {'tel': None, 'website': 'http://www.phuketbul...
# 703   {'tel': '076211959 ต่อ148', 'website': 'http:/...
# 1180  {'tel': '0 7631 1105', 'website': None, 'email...
# 1181      {'tel': None, 'website': None, 'email': None}
# 1182      {'tel': None, 'website': None, 'email': None}
# 1183  {'tel': None, 'website': 'www.phuketcity.info/...
# 1184  {'tel': '0 7628 0774, 0 7652 1334-42, 08 1958 ...
# 1185  {'tel': '0 7638 1226', 'website': 'www.watchal...
# 1221      {'tel': None, 'website': None, 'email': None}
#
#                                                new_tags  \
# 203                                          ['ดอกไม้']
# 209   ['สุโขทัย', 'พระพุทธรูป', 'รอยพระพุทธบาทจำลอง'...
# 210                                    ['รัตนโกสินทร์']
# 214   ['ภาชนะดินเผา', 'รัตนโกสินทร์', 'เจดีย์', 'ศิล...
# 215                                             ['วัด']
# 282                      ['พิพิธภัณฑ์', 'วัด', 'โบราณ']
# 461   ['วัด', 'โบราณสถาน', 'พระพุทธรูป', 'แหล่งศึกษา...
# 471                                  ['วัด', 'สักการะ']
# 512                       ['วัด', 'พระพุทธรูป', 'เกาะ']
# 605                                ['วัด', 'วัตถุมงคล']
# 653         ['วัด', 'พระพุทธรูป', 'อนุสรณ์สถาน', 'บ่อ']
# 670                       ['หาด', 'พระพุทธรูป', 'เกาะ']
# 675   ['วัด', 'รูปปั้น', 'สักการะ', 'บ่อ', 'พระราชวัง']
# 701                                           ['ชุมชน']
# 702    ['วัด', 'โบราณสถาน', 'พระพุทธรูป', 'โบราณวัตถุ']
# 703   ['วัฒนธรรมท้องถิ่น', 'วิถีชีวิต', 'บ้านเรือน',...
# 1180       ['วัด', 'พระพุทธรูป', 'วัตถุโบราณ', 'โบราณ']
# 1181  ['ประดิษฐานพระพุทธ', 'วัด', 'อุโบสถ', 'พระพุทธ...
# 1182                                     ['พระพุทธรูป']
# 1183                       ['วัด', 'พระนอน', 'สักการะ']
# 1184               ['พิพิธภัณฑ์', 'ปฏิบัติธรรม', 'วัด']
# 1185  ['พระบรมสารีริกธาตุ', 'ตำนาน', 'วัด', 'สารีริก...
# 1221                                                 []
#
#                                            new_tat_tags  latitude  longitude  \
# 203   ['ศูนย์ศึกษาธรรมชาติ/แหล่งท่องเที่ยวทางดอกไม้แ...  7.890000  98.400000
# 209   ['โบราณสถาน/ศาสนสถาน/สถานปฏิบัติธรรม', 'ศาสนสถ...  7.880000  98.390000
# 210              ['โบราณสถาน/ศาสนสถาน/สถานปฏิบัติธรรม']  7.890000  98.400000
# 214   ['โบราณสถาน', 'โบราณสถาน/ศาสนสถาน/สถานปฏิบัติธ...  8.030000  98.350000
# 215   ['ศาสนสถาน', 'โบราณสถาน/ศาสนสถาน/สถานปฏิบัติธร...  7.840000  98.340000
# 282   ['พิพิธภัณฑ์', 'อนุสาวรีย์/พิพิธภัณฑ์', 'ศาสนส...  8.034257  98.337331
# 612          612  สำนักงานปลัดกระทรวงการท่องเที่ยวและกีฬา
# 758          758  สำนักงานปลัดกระทรวงการท่องเที่ยวและกีฬา
# 791          791  สำนักงานปลัดกระทรวงการท่องเที่ยวและกีฬา
# 1238        1238               การท่องเที่ยวแห่งประเทศไทย
# 1249        1249               การท่องเที่ยวแห่งประเทศไทย
#
#                                                 title  \
# 424                 หาดในยาง (อุทยานแห่งชาติสิรินาถ)
# 439                           ชุมชนท่องเที่ยวบ้านแขนน
# 469                             อุทยานแห่งชาติสิรินาถ
# 612   หาดไม้ขาวหรือหาดสนามบิน (อุทยานแห่งชาติสิรินาถ)
# 758                  หาดลายัน (อุทยานแห่งชาติสิรินาถ)
# 791                                          หาดในทอน
# 1238                                       หาดหินกรวย
# 1249                            อุทยานแห่งชาติสิรินาถ
#
#                                                 img_url  \
# 424   ['https://www.thailandtourismdirectory.go.th/t...
# 439   ['https://www.thailandtourismdirectory.go.th/t...
# 469   ['https://www.thailandtourismdirectory.go.th/t...
# 612   ['https://www.thailandtourismdirectory.go.th/t...
# 758   ['https://www.thailandtourismdirectory.go.th/t...
# 791   ['https://www.thailandtourismdirectory.go.th/t...
# 1238                                                NaN
# 1249                                                NaN
#
#                     title_en  \
# 424                      NaN
# 439                      NaN
# 469                      NaN
# 612                      NaN
# 758                      NaN
# 791                      NaN
# 1238          Hin Kloi Beach
# 1249  Sirinath National Park
#
#                                                 payment tags  \
# 424   {'ราคาค่าเข้าชม': 'มีค่าใช้จ่าย', 'ต่างชาติผู้...  NaN
# 439   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...  NaN
# 469   {'ราคาค่าเข้าชม': 'มีค่าใช้จ่าย', 'ต่างชาติผู้...  NaN
# 612   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...  NaN
# 758   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...  NaN
# 791   {'ราคาค่าเข้าชม': 'ไม่มีค่าใช้จ่าย', 'หมายเหตุ...  NaN
# 1238           {'มีค่าใช้จ่าย': None, 'หมายเหตุ': None}  NaN
# 1249           {'มีค่าใช้จ่าย': 20.0, 'หมายเหตุ': None}  NaN
#
#                                                    info lda_tags  \
# 424   อุทยานแห่งชาติสิรินาถมีพื้นที่ครอบคลุมอยู่ในท้...      NaN
# 439   "สืบสานวัฒนธรรม กิจกรรมโนราบิก เรียนรู้วิถีชีว...      NaN
# 469   อุทยานแห่งชาติสิรินาถมีพื้นที่ครอบคลุมอยู่ในท้...      NaN
# 612   หาดไม้ขาว จ.ภูเก็ต เป็นชายหาดที่มีบรรยากาศเงีย...      NaN
# 758   หาดลายัน ที่ไม่มีสิ่งอำนวยความสะดวกใดๆ เลยนั้น...      NaN
# 791   หาดในทอน เป็นอีกหนึ่งหาดที่อยู่ในเขตอุทยานแห่ง...      NaN
# 1238                  ชายหาดขาวสะอาด เงียบสงบเล่นน้ำได้      NaN
# 1249  ชายหาดเงียบสงบร่มรื่นด้วยทิวสนและพรรณไม้ป่าชาย...      NaN
#
#                                                   hours  \
# 424   {'วันอาทิตย์': ['0500', '2200'], 'วันจันทร์': ...
# 439   {'วันอาทิตย์': ['0830', '1630'], 'วันจันทร์': ...
# 469   {'วันอาทิตย์': ['0800', '2200'], 'วันจันทร์': ...
# 612   {'วันอาทิตย์': ['0600', '2000'], 'วันจันทร์': ...
# 758   {'วันอาทิตย์': ['0700', '1800'], 'วันจันทร์': ...
# 791   {'วันอาทิตย์': ['0700', '1700'], 'วันจันทร์': ...
# 1238                                                NaN
# 1249                          เปิดทุกวัน 06.00-18.00 น.
#
#                                                contacts  \
# 424   {'tel': '076327152', 'website': 'http://portal...
# 439   {'tel': '0818956864', 'website': 'http://www.p...
# 469   {'tel': '076327152', 'website': 'http://dnp.go...
# 612   {'tel': '076328226', 'website': None, 'email':...
# 758   {'tel': None, 'website': 'http://thai.phuketre...
# 791   {'tel': None, 'website': 'http://thai.phuketre...
# 1238      {'tel': None, 'website': None, 'email': None}
# 1249  {'tel': '0 7632 8226', 'website': 'www.dnp.go....
#
#                                                new_tags  \
# 424   ['ทางทะเล', 'ทะเล', 'หาด', 'ธรรมชาติ', 'หาดทรา...
# 439   ['หมู่บ้าน', 'โบราณสถาน', 'ชุมชน', 'เรียนรู้',...
# 469   ['ทางทะเล', 'ทะเล', 'ธรรมชาติ', 'หาดทรายขาว', ...
# 612   ['หาด', 'เขตอุทยานแห่งชาติ', 'ป่าสน', 'ชายหาด'...
# 758   ['เต็นท์', 'หาด', 'ธรรมชาติ', 'กางเต็นท์', 'ชา...
# 791   ['อุทยาน', 'น้ำทะเล', 'หาด', 'เขตอุทยานแห่งชาต...
# 1238  ['ทางทะเล', 'หาด', 'ธรรมชาติ', 'ชายหาด', 'อุทย...
# 1249  ['ทางทะเล', 'ศึกษาธรรมชาติ', 'ป่าชายเลน', 'ธรร...
#
#                                            new_tat_tags  latitude  longitude  \
# 424   ['ธรรมชาติ', 'แหล่งท่องเที่ยวประเภทน้ำเค็ม', '...  8.087860  98.296664
# 439   ['ชุมชน/หมู่บ้าน', 'โบราณสถาน', 'โบราณสถาน/ศาส...  8.036490  98.346301
# 469   ['ธรรมชาติ', 'แหล่งท่องเที่ยวประเภทน้ำเค็ม', '...  8.096145  98.299543
# 612   ['แหล่งท่องเที่ยวประเภทน้ำเค็ม', 'ธรรมชาติ', '...  8.127780  98.300870
# 758   ['กิจกรรมกลางแจ้ง', 'แหล่งท่องเที่ยวประเภทน้ำเ...  8.035591  98.283659
# 791   ['อุทยาน/เขตอนุรักษ์/ป่าชายเลน', 'ศูนย์ศึกษาธร...  8.059435  98.277742
# 1238  ['ธรรมชาติ', 'แหล่งท่องเที่ยวประเภทน้ำเค็ม', '...  7.996000  98.309000
# 1249  ['ธรรมชาติ', 'อุทยาน/เขตอนุรักษ์/ป่าชายเลน', '...  8.093000  98.315000
#
#                                                 address  subdistrict  \
# 424   เลขที่ 89/1 ตำบล/แขวงสาคู อำเภอ/เขตถลาง หมู่ 1...    /แขวงสาคู
# 439   ชุมชนบ้านแขนน หมู่ 2 ต.เทพกระษัตรี อ.ถลาง จ.ภู...  เทพกระษัตรี
# 469   เลขที่ 89/1 ตำบล/แขวงสาคู อำเภอ/เขตถลาง ต.สาคู...    /แขวงสาคู
# 612   ต.ไม้ขาว อ.ถลาง จ.ภูเก็ต ต.สาคู อ.ถลาง จ.ภูเก็...       ไม้ขาว
# 758   หาดลายัน (อุทยานแห่งชาติสิรินาถ) ซอยลายัน ต.เช...     เชิงทะเล
# 791          ภูเก็ต หมู่ 5 ต.สาคู อ.ถลาง จ.ภูเก็ต 83110         สาคู
# 1238          None None None เชิงทะเล ถลาง ภูเก็ต 83110     เชิงทะเล
# 1249              None None None สาคู ถลาง ภูเก็ต 83140         สาคู
#
#       district province
# 424   /เขตถลาง   ภูเก็ต
# 439       ถลาง   ภูเก็ต
# 469   /เขตถลาง   ภูเก็ต
# 612       ถลาง   ภูเก็ต
# 758       ถลาง   ภูเก็ต
# 791       ถลาง   ภูเก็ต
# 1238      ถลาง   ภูเก็ต
# 1249      ถลาง   ภูเก็ต

# %%
def get_heatmap(df1:pd.DataFrame, df2:pd.DataFrame, filter_by:str, filter_by_2:str, count:bool, min:float, max:float):
    df_copied = df1.copy()
    df_copied.loc[:, 'LATITUDE'] = ((df_copied.loc[:, 'hotel_latitude'] * 1000).apply(np.floor)) / 1000
    df_copied.loc[:, 'LONGITUDE'] = ((df_copied.loc[:, 'hotel_longitude'] * 1000).apply(np.floor)) / 1000
    df_copied.loc[:, 'LatLonRange'] = df_copied.loc[:, 'hotel_latitude'].map(str) + '-' + df_copied.loc[:, 'hotel_longitude'].map(str)

    df_copied2 = df2.copy()
    df_copied2.loc[:, 'LATITUDE'] = ((df_copied2.loc[:, 'latitude'] * 100).apply(np.floor)) / 100
    df_copied2.loc[:, 'LONGITUDE'] = ((df_copied2.loc[:, 'longitude'] * 100).apply(np.floor)) / 100
    df_copied2.loc[:, 'LatLonRange'] = df_copied2.loc[:, 'latitude'].map(str) + '-' + df_copied2.loc[:, 'longitude'].map(str)

    df_grouped = df_copied.groupby(['LatLonRange', 'LATITUDE', 'LONGITUDE'])
    df_grouped2 = df_copied2.groupby(['LatLonRange', 'LATITUDE', 'LONGITUDE'])

    if count == True:
        filter_count = df_grouped[filter_by].agg(['count']).reset_index()
        filter_count2 = df_grouped2[filter_by_2].agg(['count']).reset_index()
        df_folium = pd.DataFrame({'Lat':filter_count['LATITUDE'],'Long':filter_count['LONGITUDE'],'Count':filter_count['count']})
        df_folium2 = pd.DataFrame({'Lat':filter_count2['LATITUDE'],'Long':filter_count2['LONGITUDE'],'Count':filter_count2['count']})
        df_folium['weight'] = df_folium['Count'] / df_folium['Count'].abs().max()
        df_folium2['weight'] = df_folium2['Count'] / df_folium2['Count'].abs().max()
    else:
        filter_avgSize = df_grouped[filter_by].agg(['mean']).reset_index()
        filter_avgSize2 = df_grouped2[filter_by_2].agg(['mean']).reset_index()
        df_folium = pd.DataFrame({'Lat':filter_avgSize['LATITUDE'],'Long':filter_avgSize['LONGITUDE'],'Count':filter_avgSize['mean']})
        df_folium2 = pd.DataFrame({'Lat':filter_avgSize2['LATITUDE'],'Long':filter_avgSize2['LONGITUDE'],'Count':filter_avgSize2['mean']})
        df_folium['weight'] = df_folium['Count'] / df_folium['Count'].abs().max()
        df_folium2['weight'] = df_folium2['Count'] / df_folium2['Count'].abs().max()


    def generateBaseMap(loc, zoom=14.5, tiles='https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png', arrr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>',crs='ESPG2263'):
        return folium.Map(location=loc,
                          control_scale=True,
                          zoom_start=zoom,
                          tiles=tiles,
                          attr=arrr)

    base_map = generateBaseMap([7.89, 98.30] )
    map_values1 = df_folium[['Lat','Long','weight']]
    map_values2 = df_folium2[['Lat','Long','weight']]
    data = map_values1.values.tolist()
    data2 = map_values2.values.tolist()
    hm = HeatMap(data,gradient={0.1: 'white',  0.5: 'yellow', 1: 'red'},
                 min_opacity=min,
                 max_opacity=max,
                 blur=15,
                 radius=30,
                 use_local_extrema=True) #.add_to(base_map)

    hm2 = HeatMap(data2,gradient={0.1: 'white', 1: 'green'},
                 min_opacity=min,
                 max_opacity=max,
                 blur=20,
                 radius=30,
                 use_local_extrema=False)

    for index, location_info in df_copied2.dropna().iterrows():
	    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["title"]).add_to(base_map)

    return base_map.add_child(hm).add_child(hm2)

# %%
    def generateBaseMap(loc, zoom=11, tiles='https://{s}.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}{r}.png', arrr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>',crs='ESPG2263'):

# %%
'https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png', {
	attribution: '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>',
	subdomains: 'abcd',
	maxZoom: 20

# %%
'https://{s}.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}{r}.png'
# Out:
# 'https://{s}.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}{r}.png'

# %%
get_heatmap(hotel_raw, only_temple, "hotel_name","title", True, 0.3, 0.9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbe92761f514a80171c86dbe89e06e04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbe92761f514a80171c86dbe89e06e04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbe92761f514a80171c86dbe89e06e04 = L.map(
#                 &quot;map_cbe92761f514a80171c86dbe89e06e04&quot;,
#                 {
#                     center: [7.89, 98.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cbe92761f514a80171c86dbe89e06e04);
#
#
#
#
#
#             var tile_layer_39e122f344caf5ffdf83be451acc3bb5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cbe92761f514a80171c86dbe89e06e04);
#
#
#             var heat_map_1668f23f78d2f9a204a6f7c0217a06c8 = L.heatLayer(
, 98.322, 0.04], [7.799, 98.336, 0.04], [7.799, 98.328, 0.04], [7.799, 98.328, 0.04], [7.799, 98.33, 0.04], [7.8, 98.337, 0.04], [7.801, 98.331, 0.04], [7.801, 98.337, 0.04], [7.801, 98.411, 0.04], [7.801, 98.32, 0.04], [7.802, 98.337, 0.04], [7.802, 98.299, 0.04], [7.803, 98.33, 0.04], [7.803, 98.337, 0.04], [7.803, 98.337, 0.04], [7.803, 98.337, 0.08], [7.803, 98.335, 0.04], [7.803, 98.336, 0.04], [7.803, 98.3, 0.12], [7.804, 98.33, 0.04], [7.804, 98.338, 0.04], [7.804, 98.331, 0.04], [7.804, 98.338, 0.2], [7.804, 98.333, 0.04], [7.805, 98.409, 0.04], [7.805, 98.332, 0.04], [7.805, 98.405, 0.04], [7.805, 98.3, 0.04], [7.805, 98.3, 0.04], [7.805, 98.333, 0.04], [7.805, 98.405, 0.04], [7.805, 98.33, 0.12], [7.806, 98.331, 0.04], [7.806, 98.3, 0.04], [7.806, 98.299, 0.04], [7.807, 98.338, 0.04], [7.807, 98.3, 0.04], [7.807, 98.409, 0.08], [7.807, 98.409, 0.04], [7.807, 98.337, 0.04], [7.808, 98.331, 0.04], [7.808, 98.389, 0.04], [7.809, 98.389, 0.04], [7.809, 98.407, 0.04], [7.809, 98.337, 0.04], [7.809, 98.327, 0.12], [7.809, 98.328, 0.04], [7.809, 98.297, 0.04], [7.809, 98.402, 0.04], [7.81, 98.339, 0.04], [7.81, 98.296, 0.04], [7.81, 98.339, 0.04], [7.81, 98.326, 0.04], [7.81, 98.326, 0.2], [7.81, 98.402, 0.04], [7.81, 98.3, 0.04], [7.81, 98.329, 0.04], [7.811, 98.302, 0.04], [7.811, 98.389, 0.04],

# %%
hotel_raw.sample(1000)
# Out:
#       Unnamed: 0 property_result_type  \
# 1363        1363       NormalProperty
# 2149        2149       NormalProperty
# 124          124       NormalProperty
# 1347        1347       NormalProperty
# 1769        1769       NormalProperty
# ...          ...                  ...
# 2023        2023       NormalProperty
# 2175        2175       NormalProperty
# 677          677       NormalProperty
# 1122        1122       NormalProperty
# 1443        1443       NormalProperty
#
#                                               highlight  \
# 1363       ['nightlife', 'beaches', 'romantic locales']
# 2149                    ['beaches', 'romantic locales']
# 124   ['shopping', 'nightlife', 'restaurants', 'beac...
# 1347                         ['restaurants', 'beaches']
# 1769                    ['beaches', 'romantic locales']
# ...                                                 ...
# 2023                         ['restaurants', 'beaches']
# 2175                    ['beaches', 'romantic locales']
# 677           ['sightseeing', 'restaurants', 'beaches']
# 1122  ['shopping', 'nightlife', 'restaurants', 'beac...
# 1443  ['shopping', 'nightlife', 'restaurants', 'beac...
#
#                                              hotel_name  award_year  \
# 1363       Kamala Beach 2 Bedroom Oceanfront Pool Villa         NaN
# 2149                                   Pyramid Bungalow         NaN
# 124          The Lantern Resort Patong (SHA Extra Plus)      2021.0
# 1347      1 bedroom bungalow with 2 single beds in Kata         NaN
# 1769                    Rawai Beach Condo Mountain View         NaN
# ...                                                 ...         ...
# 2023                                             Hostel         NaN
# 2175  Luxury Classy Private 7BR Villa in Layan-VVPHU...         NaN
# 677        Best Western Phuket Ocean Resort (SHA Plus+)         NaN
# 1122                                  The C Park Phuket         NaN
# 1443  Central Patong!3BR&Pool access luxury condo!11...         NaN
#
#            area_name property_type  rating  renovation_info_year  \
# 1363          Kamala    SingleRoom     4.0                   NaN
# 2149     Koh Yao Noi    SingleRoom     0.0                   NaN
# 124           Patong         Hotel     4.0                   NaN
# 1347            Kata    SingleRoom     4.0                   NaN
# 1769  Nai Harn Beach    SingleRoom     0.0                   NaN
# ...              ...           ...     ...                   ...
# 2023            Kata    SingleRoom     3.0                   NaN
# 2175           Layan    SingleRoom     5.0                   NaN
# 677            Karon         Hotel     4.0                   NaN
# 1122          Patong      NonHotel     2.5                   NaN
# 1443          Patong    SingleRoom     5.0                   NaN
#
#       hotel_latitude  ...  pay_at_hotel_eligible no_credit_card_eligible  \
# 1363        7.933122  ...                  False                   False
# 2149        8.106960  ...                  False                   False
# 124         7.892499  ...                  False                   False
# 1347        7.814014  ...                  False                   False
# 1769        7.769170  ...                  False                   False
# ...              ...  ...                    ...                     ...
# 2023        7.817574  ...                  False                   False
# 2175        8.042749  ...                  False                   False
# 677         7.851568  ...                  False                   False
# 1122        7.887352  ...                  False                   False
# 1443        7.885715  ...                  False                   False
#
#       cheapest_room_size                                         facilities  \
# 1363               100.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 2149                 4.0                                                 []
# 124                 28.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1347                50.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1769                24.0                                                 []
# ...                  ...                                                ...
# 2023                28.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 2175               100.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 677                 22.5  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1122                20.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1443               115.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
#
#      hotel_tag_name     hotel_view soldout_average_price  host_level_name  \
# 1363            NaN            NaN                   NaN     VerifiedHost
# 2149            NaN            NaN                   NaN              NaN
# 124             NaN            NaN                   NaN              NaN
# 1347            NaN            NaN                   NaN      RegularHost
# 1769            NaN            NaN                   NaN              NaN
# ...             ...            ...                   ...              ...
# 2023            NaN            NaN                   NaN     VerifiedHost
# 2175            NaN            NaN                   NaN     VerifiedHost
# 677             NaN       Sea View                   NaN              NaN
# 1122            NaN  Mountain View                   NaN              NaN
# 1443            NaN            NaN                   NaN     VerifiedHost
#
#      price_promotion  price_actual
# 1363        34212.50      40644.44
# 2149          453.97        539.77
# 124          1615.15       2001.12
# 1347         2338.20       2777.78
# 1769         2307.16       2507.16
# ...              ...           ...
# 2023         1104.00       1311.55
# 2175        89999.49     106919.39
# 677          2334.25       2845.51
# 1122          445.71        529.51
# 1443        62663.67      77444.44
#
# [1000 rows x 33 columns]

# %%
get_heatmap(hotel_raw.sample(100), tourism.sample(200), "hotel_name","title", True, 0.4, 0.9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b0cbc24f5e514452ab90368110c2abb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b0cbc24f5e514452ab90368110c2abb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b0cbc24f5e514452ab90368110c2abb = L.map(
#                 &quot;map_0b0cbc24f5e514452ab90368110c2abb&quot;,
#                 {
#                     center: [7.89, 98.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map
.33, 0.04], [7.8, 98.337, 0.04], [7.801, 98.331, 0.04], [7.801, 98.337, 0.04], [7.801, 98.411, 0.04], [7.801, 98.32, 0.04], [7.802, 98.337, 0.04], [7.802, 98.299, 0.04], [7.803, 98.33, 0.04], [7.803, 98.337, 0.04], [7.803, 98.337, 0.04], [7.803, 98.337, 0.08], [7.803, 98.335, 0.04], [7.803, 98.336, 0.04], [7.803, 98.3, 0.12], [7.804, 98.33, 0.04], [7.804, 98.338, 0.04], [7.804, 98.331, 0.04], [7.804, 98.338, 0.2], [7.804, 98.333, 0.04], [7.805, 98.409, 0.04], [7.805, 98.332, 0.04], [7.805, 98.405, 0.04], [7.805, 98.3, 0.04], [7.805, 98.3, 0.04], [7.805, 98.333, 0.04], [7.805, 98.405, 0.04], [7.805, 98.33, 0.12], [7.806, 98.331, 0.04], [7.806, 98.3, 0.04], [7.806, 98.299, 0.04], [7.807, 98.338, 0.04], [7.807, 98.3, 0.04], [7.807, 98.409, 0.08], [7.807, 98.409, 0.04], [7.807, 98.337, 0.04], [7.808, 98.331, 0.04], [7.808, 98.389, 0.04], [7.809, 98.389, 0.04], [7.809, 98.407, 0.04], [7.809, 98.337, 0.04], [7.809, 98.327, 0.12], [7.809, 98.328, 0.04], [7.809, 98.297, 0.04], [7.809, 98.402, 0.04], [7.81, 98.339, 0.04], [7.81, 98.296, 0.04], [7.81, 98.339, 0.04], [7.81, 98.326, 0.04], [7.81, 98.326, 0.2], [7.81, 98.402, 0.04], [7.81, 98.3, 0.04], [7.81, 98.329, 0.04], [7.811, 98.302, 0.04], [7.811, 98.389, 0.0

# %%
get_heatmap(hotel_raw, "rating")

# %%
import io
from PIL import Image

img_data = get_heatmap(hotel_raw, tourism, "hotel_name","title", True, 0.1, 0.9)
img = Image.open(io.BytesIO(img_data))
img.save('image_count_1.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30640\3922900637.py in <cell line: 6>()
#       4 get_heatmap(hotel_raw, tourism, "hotel_name","title", True, 0.1, 0.9)
#       5 img_data = get_heatmap(hotel_raw, tourism, "hotel_name","title", True, 0.1, 0.9)
# ----> 6 img = Image.open(io.BytesIO(img_data))
#       7 img.save('image_count_1.png')
#
# TypeError: a bytes-like object is required, not 'Map'

# %%
import io
from PIL import Image

get_heatmap(hotel_raw, "review_score")
img_data = get_heatmap(hotel_raw, "review_score")._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('image_count.png')

# %%
get_heatmap(hotel_raw, "review_score")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f32efaea2ecbbb5a069a2ac0a4aeba1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f32efaea2ecbbb5a069a2ac0a4aeba1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f32efaea2ecbbb5a069a2ac0a4aeba1 = L.map(
#                 &quot;map_6f32efaea2ecbbb5a069a2ac0a4aeba1&quot;,
#                 {
#                     center: [7.95, 98.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6f32efaea2ecbbb5a069a2ac0a4aeba1);
#
#
#
#
#
#             var tile_layer_638d287a59c638778632fc8b006e83db = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_
# 1               Dewa Phuket Resort & Villas (SHA Plus+)      2019.0
# 2                  The SIS Kata Resort (SHA Extra Plus)         NaN
# 3     Phuket Marriott Resort & Spa, Merlin Beach SHA...         NaN
# 4                  Kalima Resort & Spa (SHA Extra plus)         NaN
# ...                                                 ...         ...
# 2270                   The Regent Bangtao Phuket by VIP         NaN
# 2271                                        Cello Hotel         NaN
# 2272                                 3plus1hostelphuket         NaN
# 2273                                          7Q Patong         NaN
# 2274                                   Villa Leelawadee         NaN
#
#           area_name property_type  rating  renovation_info_year  \
# 0       Phuket Town         Hotel     5.0                2021.0
# 1     Naiyang Beach         Hotel     5.0                   NaN
# 2              Kata         Hotel     5.0                   NaN
# 3            Patong         Hotel     5.0                   NaN
# 4            Patong         Hotel     5.0                2021.0
# ...             ...           ...     ...                   ...
# 2270      Bang Thao      NonHotel     4.5                   NaN
# 2271         Patong         Hotel     2.0                   NaN
# 2272         Patong         Hotel     3.0                   NaN
# 2273         Patong         Hotel     3.0                   NaN
# 2274         Ao Por         Hotel     4.0                   NaN
#
#       hotel_latitude  ...  pay_at_hotel_eligible no_credit_card_eligible  \
# 0           7.882801  ...                   True                   False
# 1           8.092709  ...                  False                   False
# 2           7.812412  ...                  False                   False
# 3           7.883696  ...                    NaN                     NaN
# 4           7.917336  ...                  False                   False
# ...              ...  ...                    ...                     ...
# 2270        7.994883  ...                  False                   False
# 2271        7.890340  ...                  False                   False
# 2272        7.898893  ...                    NaN                     NaN
# 2273        7.905789  ...                  False                   False
# 2274        8.076360  ...                  False                   False
#
#       cheapest_room_size                                         facilities  \
# 0                   30.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1                   38.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 2                    NaN  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 3                    NaN  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 4                   46.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# ...                  ...                                                ...
# 2270                 NaN                                                 []
# 2271                 NaN                                                 []
# 2272                 NaN                                                 []
# 2273                 NaN                                                 []
# 2274                 NaN                                                 []
#
#      hotel_tag_name hotel_view soldout_average_price  host_level_name  \
# 0               NaN        NaN                   NaN              NaN
# 1               NaN        NaN                   NaN              NaN
# 2               NaN        NaN                   NaN              NaN
# 3            Luxury   Sea View           8618.061916              NaN
# 4               NaN   Sea View                   NaN              NaN
# ...             ...        ...                   ...              ...
# 2270            NaN        NaN                   NaN              NaN
# 2271            NaN        NaN                   NaN              NaN
# 2272            NaN        NaN             72.864480              NaN
# 2273            NaN        NaN                   NaN              NaN
# 2274            NaN        NaN                   NaN              NaN
#
#      price_promotion  price_actual
# 0            1611.26       1914.18
# 1            2215.51       2630.08
# 2            1997.28       2372.77
# 3               0.00          0.00
# 4            3132.00       3720.82
# ...              ...           ...
# 2270            0.00          0.00
# 2271            0.00          0.00
# 2272            0.00          0.00
# 2273            0.00          0.00
# 2274            0.00          0.00
#
# [2275 rows x 33 columns]

# %%
fire_avgSize
# Out:
#                               LatLonRange  LATITUDE  LONGITUDE    mean
# 0     7.601505488952187-98.37462919201585      7.60      98.37    26.0
# 1       7.60158678208239-98.3749616146088      7.60      98.37  1393.0
# 2       7.60746764779394-98.3690822124481      7.60      98.36  1983.0
# 3     7.609296798706055-98.36986541748048      7.60      98.36  2752.0
# 4          7.765769958496094-98.310546875      7.76      98.31    38.0
# ...                                   ...       ...        ...     ...
# 2048                  8.2855256-98.305517      8.28      98.30   190.0
# 2049   8.285792681871683-98.3048442902199      8.28      98.30    13.0
# 2050    8.28761804806964-98.2745550872642      8.28      98.27   625.0
# 2051    8.289614722528102-98.273839746358      8.28      98.27     NaN
# 2052     8.2995433807373-98.2721099853516      8.29      98.27   281.0
#
# [2053 rows x 4 columns]

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap
m = folium.Map(location=[45.5236, -122.6750], tiles="Stamen Terrain")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4877439665d67850c15e4510749129f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4877439665d67850c15e4510749129f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4877439665d67850c15e4510749129f = L.map(
#                 &quot;map_c4877439665d67850c15e4510749129f&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2305d81e44ed75d5bfd53d4825dc73ec = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4877439665d67850c15e4510749129f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fire_count
# Out:
#                               LatLonRange  LATITUDE  LONGITUDE  count
# 0     7.601505488952187-98.37462919201585      7.60      98.37      1
# 1       7.60158678208239-98.3749616146088      7.60      98.37      1
# 2       7.60746764779394-98.3690822124481      7.60      98.36      1
# 3     7.609296798706055-98.36986541748048      7.60      98.36      1
# 4          7.765769958496094-98.310546875      7.76      98.31      1
# ...                                   ...       ...        ...    ...
# 2048                  8.2855256-98.305517      8.28      98.30      1
# 2049   8.285792681871683-98.3048442902199      8.28      98.30      1
# 2050    8.28761804806964-98.2745550872642      8.28      98.27      1
# 2051    8.289614722528102-98.273839746358      8.28      98.27      0
# 2052     8.2995433807373-98.2721099853516      8.29      98.27      1
#
# [2053 rows x 4 columns]

# %%
df_folium = pd.DataFrame({'Lat':fire_count['LATITUDE'],'Long':fire_count['LONGITUDE'],'Count':fire_count['count']})
df_folium['weight'] = df_folium['Count'] / df_folium['Count'].abs().max()

def generateBaseMap(loc, zoom=11, tiles="Stamen Terrain", crs='ESPG2263'):
	return folium.Map(location=loc,
	                  control_scale=True,
	                  zoom_start=zoom,
	                  tiles=tiles)

base_map = generateBaseMap([7.95, 98.33] )

map_values1 = df_folium[['Lat','Long','weight']]

data = map_values1.values.tolist()

hm = HeatMap(data,gradient={0.1: 'blue', 0.3: 'lime', 0.5: 'yellow', 0.7: 'orange', 1: 'red'},
             min_opacity=0.05,
             max_opacity=0.9,
             radius=35,
             use_local_extrema=False) #.add_to(base_map)

base_map.add_child(hm)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4d1e175baaa712e9e2a705419eb099b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4d1e175baaa712e9e2a705419eb099b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4d1e175baaa712e9e2a705419eb099b = L.map(
#                 &quot;map_d4d1e175baaa712e9e2a705419eb099b&quot;,
#                 {
#                     center: [7.95, 98.33],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d4d1e175baaa712e9e2a705419eb099b);
#
#
#
#
#
#             var tile_layer_b0b130e2887e31d734eaa52a6b17cbc3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_
# 2273  ['shopping', 'nightlife', 'restaurants', 'beac...
# 2274               ['convenient public transportation']
#
#                                              hotel_name  award_year  \
# 0              Royal Phuket City Hotel (SHA Extra Plus)         NaN
# 1               Dewa Phuket Resort & Villas (SHA Plus+)      2019.0
# 2                  The SIS Kata Resort (SHA Extra Plus)         NaN
# 3     Phuket Marriott Resort & Spa, Merlin Beach SHA...         NaN
# 4                  Kalima Resort & Spa (SHA Extra plus)         NaN
# ...                                                 ...         ...
# 2270                   The Regent Bangtao Phuket by VIP         NaN
# 2271                                        Cello Hotel         NaN
# 2272                                 3plus1hostelphuket         NaN
# 2273                                          7Q Patong         NaN
# 2274                                   Villa Leelawadee         NaN
#
#           area_name property_type  rating  renovation_info_year  \
# 0       Phuket Town         Hotel     5.0                2021.0
# 1     Naiyang Beach         Hotel     5.0                   NaN
# 2              Kata         Hotel     5.0                   NaN
# 3            Patong         Hotel     5.0                   NaN
# 4            Patong         Hotel     5.0                2021.0
# ...             ...           ...     ...                   ...
# 2270      Bang Thao      NonHotel     4.5                   NaN
# 2271         Patong         Hotel     2.0                   NaN
# 2272         Patong         Hotel     3.0                   NaN
# 2273         Patong         Hotel     3.0                   NaN
# 2274         Ao Por         Hotel     4.0                   NaN
#
#       hotel_latitude  ...  pay_at_hotel_eligible no_credit_card_eligible  \
# 0           7.882801  ...                   True                   False
# 1           8.092709  ...                  False                   False
# 2           7.812412  ...                  False                   False
# 3           7.883696  ...                    NaN                     NaN
# 4           7.917336  ...                  False                   False
# ...              ...  ...                    ...                     ...
# 2270        7.994883  ...                  False                   False
# 2271        7.890340  ...                  False                   False
# 2272        7.898893  ...                    NaN                     NaN
# 2273        7.905789  ...                  False                   False
# 2274        8.076360  ...                  False                   False
#
#       cheapest_room_size                                         facilities  \
# 0                   30.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 1                   38.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 2                    NaN  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 3                    NaN  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# 4                   46.0  ['Wi-Fi [free]', 'Balcony/terrace', 'Desk', 'P...
# ...                  ...                                                ...
# 2270                 NaN                                                 []
# 2271                 NaN                                                 []
# 2272                 NaN                                                 []
# 2273                 NaN                                                 []
# 2274                 NaN                                                 []
#
#      hotel_tag_name hotel_view soldout_average_price  host_level_name  \
# 0               NaN        NaN                   NaN              NaN
# 1               NaN        NaN                   NaN              NaN
# 2               NaN        NaN                   NaN              NaN
# 3            Luxury   Sea View           8618.061916              NaN
# 4               NaN   Sea View                   NaN              NaN
# ...             ...        ...                   ...              ...
# 2270            NaN        NaN                   NaN              NaN
# 2271            NaN        NaN                   NaN              NaN
# 2272            NaN        NaN             72.864480              NaN
# 2273            NaN        NaN                   NaN              NaN
# 2274            NaN        NaN                   NaN              NaN
#
#      price_promotion  price_actual
# 0            1611.26       1914.18
# 1            2215.51       2630.08
# 2            1997.28       2372.77
# 3               0.00          0.00
# 4            3132.00       3720.82
# ...              ...           ...
# 2270            0.00          0.00
# 2271            0.00          0.00
# 2272            0.00          0.00
# 2273            0.00          0.00
# 2274            0.00          0.00
#
# [2275 rows x 33 columns]
